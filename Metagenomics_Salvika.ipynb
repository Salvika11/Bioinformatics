# %% [markdown]
# <a href="https://colab.research.google.com/github/Salvika11/Bioinformatics/blob/main/Metagenomics_Salvika.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# ---------------------------------------------------------
# 1. Data Simulation (Creating a Mock OTU Table)
# ---------------------------------------------------------
# In a real scenario, this data would come from a CSV file generated
# by a sequencing pipeline (e.g., QIIME2, Mothur).
np.random.seed(42)
taxa = [f"Species_{i}" for i in range(1, 31)]
samples = ['Sample_A', 'Sample_B', 'Sample_C', 'Sample_D'] # 4 samples

# Generate random counts (reads) for each species in each sample
data = np.random.randint(0, 100, size=(30, 4))
df = pd.DataFrame(data, index=taxa, columns=samples)

print("--- Generated OTU Table (First 5 Rows) ---")
print(df.head())
print("\n")

# ---------------------------------------------------------
# 2. Alpha Diversity Analysis (Shannon Index)
# ---------------------------------------------------------
# Formula: H = -sum(p_i * ln(p_i))
def calculate_shannon_index(counts):
  total = sum(counts)
  if total == 0: return 0
  proportions = counts / total
  # Filter out zeros to avoid log(0) error
  proportions = proportions[proportions > 0]
  return -np.sum(proportions * np.log(proportions))

alpha_diversity = df.apply(calculate_shannon_index)

print("--- Alpha Diversity (Shannon Index) ---")
print(alpha_diversity)
print("\n")

# ---------------------------------------------------------
# 3. Relative Abundance Calculation
# ---------------------------------------------------------
# Normalize raw counts to percentages (sum of column = 100%)
relative_abundance = df.div(df.sum(axis=0), axis=1) * 100

print("--- Relative Abundance Table Shape ---")
print(relative_abundance.shape)
print("\n--- Relative Abundance Table (First 5 Rows) ---")
print(relative_abundance.head())
print("\n")

# ---------------------------------------------------------
# 4. Visualization
# ---------------------------------------------------------
plt.figure(figsize=(14, 6))

# Plot 1: Alpha Diversity
plt.subplot(1, 2, 1)
sns.barplot(x=alpha_diversity.index, y=alpha_diversity.values, palette='viridis', hue=alpha_diversity.index, legend=False)
plt.title('Alpha Diversity (Shannon Index)\n(Higher = More Diverse)')
plt.ylabel('Shannon Index')
plt.xlabel('Samples')

# Plot 2: Stacked Bar Chart of Relative Abundance
plt.subplot(1, 2, 2)
# We plot the transpose (.T) so samples are on the X-axis
relative_abundance.T.plot(kind='bar', stacked=True, ax=plt.gca(), colormap='tab20')
plt.title('Relative Abundance of Species')
plt.ylabel('Percentage (%)')
plt.xlabel('Samples')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', title="Taxa")

plt.tight_layout()
plt.show()
# Out:
# --- Generated OTU Table (First 5 Rows) ---
#            Sample_A  Sample_B  Sample_C  Sample_D
# Species_1        51        92        14        71
# Species_2        60        20        82        86
# Species_3        74        74        87        99
# Species_4        23         2        21        52
# Species_5         1        87        29        37
#
#
# --- Alpha Diversity (Shannon Index) ---
# Sample_A    3.099134
# Sample_B    3.239619
# Sample_C    3.194194
# Sample_D    3.194816
# dtype: float64
#
#
# --- Relative Abundance Table Shape ---
# (30, 4)
#
# --- Relative Abundance Table (First 5 Rows) ---
#            Sample_A  Sample_B  Sample_C  Sample_D
# Species_1  3.536755  5.555556  1.051841  4.649640
# Species_2  4.160888  1.207729  6.160781  5.631958
# Species_3  5.131761  4.468599  6.536439  6.483301
# Species_4  1.595007  0.120773  1.577761  3.405370
# Species_5  0.069348  5.253623  2.178813  2.423052

# %%
pip install pandas scikit-bio matplotlib seaborn numpy
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Collecting scikit-bio
#   Downloading scikit_bio-0.7.1.post1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from scikit-bio) (2.32.4)
# Requirement already satisfied: decorator>=3.4.2 in /usr/local/lib/python3.12/dist-packages (from scikit-bio) (4.4.2)
# Requirement already satisfied: natsort>=4.0.3 in /usr/local/lib/python3.12/dist-packages (from scikit-bio) (8.4.0)
# Requirement already satisfied: scipy>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from scikit-bio) (1.16.3)
# Requirement already satisfied: h5py>=3.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-bio) (3.15.1)
# Collecting biom-format>=2.1.16 (from scikit-bio)
#   Downloading biom_format-2.1.17-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: statsmodels>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from scikit-bio) (0.14.5)
# Requirement already satisfied: patsy>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from scikit-bio) (1.0.2)
# Collecting array-api-compat>=1.3 (from scikit-bio)
#   Downloading array_api_compat-1.12.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from biom-format>=2.1.16->scikit-bio) (8.3.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20.0->scikit-bio) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20.0->scikit-bio) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20.0->scikit-bio) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20.0->scikit-bio) (2025.11.12)
# Downloading scikit_bio-0.7.1.post1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 55.1 MB/s eta 0:00:00
# Downloading array_api_compat-1.12.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.2/58.2 kB 2.8 MB/s eta 0:00:00
# Downloading biom_format-2.1.17-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 59.8 MB/s eta 0:00:00
# Installing collected packages: array-api-compat, biom-format, scikit-bio
# Successfully installed array-api-compat-1.12.0 biom-format-2.1.17 scikit-bio-0.7.1.post1

# %%
import subprocess
import os
import glob

def run_command(cmd, description):
  """Helper to run shell commands with error handling."""
  print(f"--- Running: {description} ---")
  try:
    # shell=True allows using wildcards like *.fastq
    subprocess.run(cmd, shell=True, check=True)
    print(f"--- Finished: {description} ---\n")
  except subprocess.CalledProcessError as e:
    print(f"!!! Error in {description}: {e}")
    # exit(1) # Removed exit to allow other parts of the script to run if one command fails

def pipeline(input_dir, output_dir):
  os.makedirs(output_dir, exist_ok=True)

  # 1. Quality Control (using fastp)
  # Assumes paired-end reads R1 and R2
  r1_files = sorted(glob.glob(f"{input_dir}/*_R1.fastq.gz"))
  r2_files = sorted(glob.glob(f"{input_dir}/*_R2.fastq.gz"))

  qc_dir = os.path.join(output_dir, "qc_reads")
  os.makedirs(qc_dir, exist_ok=True)

  if not r1_files or not r2_files:
      print("No raw fastq.gz files found. Skipping QC and Assembly.")
  else:
      for r1, r2 in zip(r1_files, r2_files):
        sample_name = os.path.basename(r1).split("_R1")[0]

        qc_cmd = (
        f"fastp -i {r1} -I {r2} "
        f"-o {qc_dir}/{sample_name}_R1_clean.fastq.gz "
        f"-O {qc_dir}/{sample_name}_R2_clean.fastq.gz "
        f"-h {qc_dir}/{sample_name}_fastp.html -j {qc_dir}/{sample_name}_fastp.json"
        )
        run_command(qc_cmd, f"QC for {sample_name}")

      # 2. Assembly (using MEGAHIT)
      # We co-assemble all clean reads for this example
      assembly_out = os.path.join(output_dir, "assembly")
      os.makedirs(assembly_out, exist_ok=True)
      reads_1 = ",".join(glob.glob(f"{qc_dir}/*_R1_clean.fastq.gz"))
      reads_2 = ",".join(glob.glob(f"{qc_dir}/*_R2_clean.fastq.gz"))

      if reads_1 and reads_2:
          assemble_cmd = (
          f"megahit -1 {reads_1} -2 {reads_2} "
          f"-o {assembly_out} --out-prefix metagenome_assembly"
          )
          run_command(assemble_cmd, "Metagenome Assembly")
      else:
          print("No cleaned reads found for assembly. Skipping Assembly.")

  # 3. Taxonomic Classification (using Kraken2)
  # Note: Requires a pre-built Kraken2 database
  kraken_db = "/path/to/kraken_db" # Placeholder: Kraken2 DB is usually very large and needs to be downloaded/built separately
  taxonomy_out = os.path.join(output_dir, "taxonomy")
  os.makedirs(taxonomy_out, exist_ok=True)

  # The classification step is commented out because it requires a Kraken2 database
  # and the megahit output (metagenome_assembly.contigs.fa) which might not be generated
  # if megahit fails or is skipped.
  # classify_cmd = (
  # f"kraken2 --db {kraken_db} --threads 8 --output {taxonomy_out}/kraken.output "
  # f"--report {taxonomy_out}/kraken_report.txt "
  # f"{assembly_out}/metagenome_assembly.contigs.fa"
  # )
  # run_command(classify_cmd, "Kraken2 Classification") # Uncomment if DB is available


# !pip install scikit-bio
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from skbio.diversity import alpha_diversity, beta_diversity
from skbio.stats.ordination import pcoa

if __name__ == "__main__":
# Example usage for the pipeline function (will likely fail if fastp/megahit not installed or no data)
  # pipeline(input_dir="./raw_data", output_dir="./results")
  print("Skipping pipeline execution for now to demonstrate skbio functionality.")

# 1. Load Data (Creating a mock dataset for demonstration)
# Rows = Samples, Columns = Species (Taxa)
data = {
'E. coli': [10, 50, 200, 15, 5],
'S. aureus': [50, 10, 5, 80, 100],
'P. aeruginosa': [100, 120, 10, 20, 30],
'B. subtilis': [5, 5, 50, 100, 150],
'L. acidophilus': [200, 180, 20, 10, 5]
}
sample_ids = ['Sample_A', 'Sample_B', 'Sample_C', 'Sample_D', 'Sample_E']
groups = ['Gut', 'Gut', 'Skin', 'Skin', 'Skin'] # Metadata for coloring

df = pd.DataFrame(data, index=sample_ids)
print("--- Abundance Table ---")
print(df.head())

# 2. Alpha Diversity (Within-sample diversity)
# Metrics: 'shannon', 'simpson', 'chao1'
alpha_shannon = alpha_diversity('shannon', df.values, ids=sample_ids)
alpha_observed = alpha_diversity('observed_features', df.values, ids=sample_ids)

# Combine into a result DataFrame
alpha_results = pd.DataFrame({
'Shannon': alpha_shannon,
'Observed_Species': alpha_observed,
'Group': groups
}, index=sample_ids)

print("\n--- Alpha Diversity ---")
print(alpha_results)

# 3. Beta Diversity (Between-sample diversity)
# Metric: 'braycurtis' is common for abundance data
distance_matrix = beta_diversity('braycurtis', df.values, ids=sample_ids)

print("\n--- Bray-Curtis Distance Matrix ---")
print(distance_matrix)

# 4. PCoA (Principal Coordinates Analysis)
# Dimensionality reduction to visualize the distance matrix
pcoa_results = pcoa(distance_matrix)

# Plotting PCoA
plt.figure(figsize=(8, 6))
pcoa_df = pcoa_results.samples
pcoa_df['Group'] = groups

sns.scatterplot(x='PC1', y='PC2', hue='Group', style='Group', s=100, data=pcoa_df)

# Add percentage explanation to axes
pc1_pct = pcoa_results.proportion_explained['PC1'] * 100
pc2_pct = pcoa_results.proportion_explained['PC2'] * 100
plt.xlabel(f'PC1 ({pc1_pct:.1f}%)')
plt.ylabel(f'PC2 ({pc2_pct:.1f}%)')
plt.title('PCoA of Microbiome Samples (Bray-Curtis)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# 5. Taxonomy Bar Plot (Stacked)
# Normalize data to relative abundance (0 to 1)
df_rel = df.div(df.sum(axis=1), axis=0)

df_rel.plot(kind='bar', stacked=True, colormap='viridis', figsize=(10, 6))
plt.ylabel('Relative Abundance')
plt.title('Taxonomic Composition')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# Requirement already satisfied: scikit-bio in /usr/local/lib/python3.12/dist-packages (0.7.1.post1)
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from scikit-bio) (2.32.4)
# Requirement already satisfied: decorator>=3.4.2 in /usr/local/lib/python3.12/dist-packages (from scikit-bio) (4.4.2)
# Requirement already satisfied: natsort>=4.0.3 in /usr/local/lib/python3.12/dist-packages (from scikit-bio) (8.4.0)
# Requirement already satisfied: numpy>=2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-bio) (2.0.2)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from scikit-bio) (2.2.2)
# Requirement already satisfied: scipy>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from scikit-bio) (1.16.3)
# Requirement already satisfied: h5py>=3.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-bio) (3.15.1)
# Requirement already satisfied: biom-format>=2.1.16 in /usr/local/lib/python3.12/dist-packages (from scikit-bio) (2.1.17)
# Requirement already satisfied: statsmodels>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from scikit-bio) (0.14.5)
# Requirement already satisfied: patsy>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from scikit-bio) (1.0.2)
# Requirement already satisfied: array-api-compat>=1.3 in /usr/local/lib/python3.12/dist-packages (from scikit-bio) (1.12.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from biom-format>=2.1.16->scikit-bio) (8.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->scikit-bio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->scikit-bio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->scikit-bio) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20.0->scikit-bio) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20.0->scikit-bio) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20.0->scikit-bio) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20.0->scikit-bio) (2025.11.12)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.14.0->scikit-bio) (25.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->scikit-bio) (1.17.0)
# Skipping pipeline execution for now to demonstrate skbio functionality.
# --- Abundance Table ---
#           E. coli  S. aureus  P. aeruginosa  B. subtilis  L. acidophilus
# Sample_A       10         50            100            5             200
# Sample_B       50         10            120            5             180
# Sample_C      200          5             10           50              20
# Sample_D       15         80             20          100              10
# Sample_E        5        100             30          150               5
#
# --- Alpha Diversity ---
#            Shannon  Observed_Species Group
# Sample_A  1.113994                 5   Gut
# Sample_B  1.143992                 5   Gut
# Sample_C  0.928797                 5  Skin
# Sample_D  1.262143                 5  Skin
# Sample_E  1.082837                 5  Skin
#
# --- Bray-Curtis Distance Matrix ---
# 5x5 distance matrix
# IDs:
# 'Sample_A', 'Sample_B', 'Sample_C', 'Sample_D', 'Sample_E'
# Data:
# [[0.         0.16438356 0.84615385 0.6779661  0.70992366]
#  [0.16438356 0.         0.72307692 0.79661017 0.83206107]
#  [0.84615385 0.72307692 0.         0.64705882 0.73913043]
#  [0.6779661  0.79661017 0.64705882 0.         0.18446602]
#  [0.70992366 0.83206107 0.73913043 0.18446602 0.        ]]
# /usr/local/lib/python3.12/dist-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:275: RuntimeWarning: The result contains negative eigenvalues that are large in magnitude, which may suggest result inaccuracy. See Notes for details. The negative-most eigenvalue is -0.023055060557080856 whereas the largest positive one is 0.5761609098205965.
#   warn(
